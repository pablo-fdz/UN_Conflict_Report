# %% [markdown]
# # Newsdata.IO
#
# With the free tier, we can make 200 searches per day and retrieve 10 articles per request (see https://newsdata.io/pricing). The metadata that is available is:
# - Title.
# - Link.
# - Date.
# - Author.
# - Publisher.
# - Country.
# - Language.
# - Description.
#
# The full text, however, is not available (it should be directly scraped).
#
# They also have available a [python client](https://newsdata.io/documentation/#client_py), check out the [GitHub](https://github.com/bytesview/python-client) and the [guide](https://newsdata.io/blog/news-api-python-client/). It doesn't seem to add much, though.

# %% [markdown]
# # Setup

# %%
from dotenv import load_dotenv
import os
import requests
from pprint import pprint

# %%
# Load environment variables from .env file
load_dotenv()

# Access the API key
api_key = os.getenv("NEWSDATA_API_KEY")
print(f"API Key loaded: {api_key[:3]}..." if api_key else "No API key found")
# Out:
# API Key loaded: pub...

# %% [markdown]
# # Making a request
#
# See the [documentation](https://newsdata.io/documentation/#first-api-request).
#
# Example for searching latest news articles with the keyword "pizza": https://newsdata.io/api/1/latest?apikey=pub_857112301fae34e55b800f06711f2df4d7b25&q=pizza. So first comes the API key, then `&q=` and then the query.

# %%
website = 'https://newsdata.io/api/1/'

search = 'latest?'

query = 'conflict in zimbabwe'

url = website + search + 'apikey=' + api_key + '&q=' + query

example = requests.get(url = url)

print(url)

print(example)
# Out:
# https://newsdata.io/api/1/latest?apikey=pub_857112301fae34e55b800f06711f2df4d7b25&q=conflict in zimbabwe
# <Response [200]>

# %%
# Inspect the response status code and headers
print(example.status_code)
pprint(example.headers)
# Out:
# 200
# {'Date': 'Thu, 08 May 2025 15:57:20 GMT', 'Server': 'Apache/2.4.41 (Ubuntu)', 'x_rate_limit_remaining': '29', 'x_api_limit_remaining': '199', 'Access-Control-Allow-Origin': '*', 'Vary': 'Accept-Encoding', 'Content-Encoding': 'gzip', 'Keep-Alive': 'timeout=5, max=100', 'Connection': 'Keep-Alive', 'Transfer-Encoding': 'chunked', 'Content-Type': 'application/json'}

# %%
# Convert the response to JSON
response_json = example.json()
pprint(response_json, indent=2, width=100)
# Out:
# { 'nextPage': '1746585892676231727',
#   'results': [ { 'ai_org': 'ONLY AVAILABLE IN CORPORATE PLANS',
#                  'ai_region': 'ONLY AVAILABLE IN CORPORATE PLANS',
#                  'ai_tag': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS',
#                  'article_id': 'eee9c04dcadf09089732cfee0b749f7b',
#                  'category': ['top'],
#                  'content': 'ONLY AVAILABLE IN PAID PLANS',
#                  'country': ['zimbabwe'],
#                  'creator': ['daglous masveta'],
#                  'description': 'Wallace Ruzvidzo Herald Reporter SENEGAL supports Zimbabwe’s '
#                                 'regional and continental leadership and is throwing its weight '
#                                 'behind Zimbabwe’s bid for a non-permanent seat in the United '
#                                 'Nations Security Council (UNSC)...The post Senegal backs Zim UNSC '
#                                 'seat bid appeared first on herald.',
#                  'duplicate': False,
#                  'image_url': 'https://www.heraldonline.co.zw/wp-content/uploads/2025/05/S2.jpg',
#                  'keywords': ['africa', 'national', 'herald'],
#                  'language': 'english',
#                  'link': 'https://www.heraldonline.co.zw/senegal-backs-zim-unsc-seat-bid/',
#                  'pubDate': '2025-05-07 22:08:38',
#                  'pubDateTZ': 'UTC',
#                  'sentiment': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS',
#                  'sentiment_stats': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS',
#                  'source_icon': 'https://i.bytvi.com/domain_icons/herald_zw.png',
#                  'source_id': 'herald_zw',
#                  'source_name': 'The Herald',
#                  'source_priority': 445177,
#                  'source_url': 'https://www.herald.co.zw',
#                  'title': 'Senegal backs Zim UNSC seat bid',
#                  'video_url': None},
#                { 'ai_org': 'ONLY AVAILABLE IN CORPORATE PLANS',
#                  'ai_region': 'ONLY AVAILABLE IN CORPORATE PLANS',
#                  'ai_tag': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS',
#                  'article_id': 'bece215afb522e4ba601a021f4fcba96',
#                  'category': ['top'],
#                  'content': 'ONLY AVAILABLE IN PAID PLANS',
#                  'country': ['zimbabwe'],
#                  'creator': ['Online Reporter'],
#                  'description': 'Trust Khosa Zimpapers Arts, Entertainment Hub JAH PRAYZAH has '
#                                 'further enriched his discography with the release of his latest '
#                                 'album, “Ndini Mukudzei,” now available to fans. Launched on May '
#                                 '3...The post Jah Prayzah bridges culture, modernity in ‘Ndini '
#                                 'Mukudzei’ appeared first on herald.',
#                  'duplicate': False,
#                  'image_url': None,
#                  'keywords': ['entertainment', 'herald'],
#                  'language': 'english',
#                  'link': 'https://www.heraldonline.co.zw/jah-prayzah-bridges-culture-modernity-in-ndini-mukudzei/',
#                  'pubDate': '2025-05-07 22:03:33',
#                  'pubDateTZ': 'UTC',
#                  'sentiment': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS',
#                  'sentiment_stats': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS',
#                  'source_icon': 'https://i.bytvi.com/domain_icons/businessweeklyzw.png',
#                  'source_id': 'businessweeklyzw',
#                  'source_name': 'Ebusiness Weekly',
#                  'source_priority': 383660,
#                  'source_url': 'https://www.businessweekly.co.zw',
#                  'title': 'Jah Prayzah bridges culture, modernity in ‘Ndini Mukudzei’',
#                  'video_url': None},
#                { 'ai_org': 'ONLY AVAILABLE IN CORPORATE PLANS',
#                  'ai_region': 'ONLY AVAILABLE IN CORPORATE PLANS',
#                  'ai_tag': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS',
#                  'article_id': 'f5bd07dd285e8a81eaa63981f6606ef5',
#                  'category': ['top'],
#                  'content': 'ONLY AVAILABLE IN PAID PLANS',
#                  'country': ['belgium'],
#                  'creator': ['Redactie'],
#                  'description': 'Volg alle ontwikkelingen over de oorlog in Oekraïne in onze '
#                                 'liveblog.',
#                  'duplicate': False,
#                  'image_url': 'https://images.hln.be/YTNkOGY3ZjZkNjU0Mjg0Nzg1MzEvZGlvLzI1NzIwODIwNC9maXQtd2lkdGgvNDAw/russia-s-president-vladimir-putin-attends-a-meeting-with-congo-republic-s-president-denis-sassou-nguesso-at-the-kremlin-in-moscow-russia-may-7-2025-alexander-nemenov-pool-via-reuters',
#                  'keywords': None,
#                  'language': 'dutch',
#                  'link': 'https://www.hln.be/buitenland/russische-media-melden-start-driedaags-bestand-kiev-noemt-eenzijdig-staakt-het-vuren-stukje-theater~va2c6d779/',
#                  'pubDate': '2025-05-07 21:38:00',
#                  'pubDateTZ': 'UTC',
#                  'sentiment': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS',
#                  'sentiment_stats': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS',
#                  'source_icon': 'https://i.bytvi.com/domain_icons/hln.png',
#                  'source_id': 'hln',
#                  'source_name': 'Hln',
#                  'source_priority': 177245,
#                  'source_url': 'https://www.hln.be',
#                  'title': 'Russische media melden start driedaags bestand, Kiev noemt eenzijdig '
#                           'staakt-het-vuren “stukje theater”',
#                  'video_url': None},
#                { 'ai_org': 'ONLY AVAILABLE IN CORPORATE PLANS',
#                  'ai_region': 'ONLY AVAILABLE IN CORPORATE PLANS',
#                  'ai_tag': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS',
#                  'article_id': '663d949b000b4e5b0aff0a7701a64eb6',
#                  'category': ['top'],
#                  'content': 'ONLY AVAILABLE IN PAID PLANS',
#                  'country': ['australia'],
#                  'creator': ['Chris Leadbeater'],
#                  'description': 'The great and the good were once lured to these dead five-stars, '
#                                 'but now they are eerily derelict – though some could yet be '
#                                 'reborn.',
#                  'duplicate': True,
#                  'image_url': 'https://static.ffx.io/images/$zoom_0.2488251879699248,$multiply_0.7554,$ratio_1.777778,$width_1059,$x_0,$y_25/t_crop_custom/q_86,f_auto/c6276605c7dcf95114ef44834000961e182e9bbe',
#                  'keywords': ['travel / inspiration'],
#                  'language': 'english',
#                  'link': 'https://www.smh.com.au/traveller/inspiration/once-the-pinnacle-of-luxury-these-10-hotels-now-sit-abandoned-20250506-p5lx2w.html',
#                  'pubDate': '2025-05-07 19:00:00',
#                  'pubDateTZ': 'UTC',
#                  'sentiment': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS',
#                  'sentiment_stats': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS',
#                  'source_icon': 'https://i.bytvi.com/domain_icons/smh.png',
#                  'source_id': 'smh',
#                  'source_name': 'The Sydney Morning Herald',
#                  'source_priority': 2251,
#                  'source_url': 'https://www.smh.com.au',
#                  'title': 'Once the pinnacle of luxury, these 10 hotels now sit abandoned',
#                  'video_url': None},
#                { 'ai_org': 'ONLY AVAILABLE IN CORPORATE PLANS',
#                  'ai_region': 'ONLY AVAILABLE IN CORPORATE PLANS',
#                  'ai_tag': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS',
#                  'article_id': 'bb86f674b75a53342640f40c82a828aa',
#                  'category': ['top'],
#                  'content': 'ONLY AVAILABLE IN PAID PLANS',
#                  'country': ['australia'],
#                  'creator': ['Chris Leadbeater'],
#                  'description': 'The great and the good were once lured to these dead five-stars, '
#                                 'but now they are eerily derelict – though some could yet be '
#                                 'reborn.',
#                  'duplicate': False,
#                  'image_url': 'https://static.ffx.io/images/$zoom_0.263,$multiply_0.7725,$ratio_1.5,$width_756,$x_17,$y_0/t_crop_custom/q_86,f_auto/3fbe264f9fdeb5ebaedb39292b67b494612a1fca',
#                  'keywords': ['travel / inspiration'],
#                  'language': 'english',
#                  'link': 'https://www.brisbanetimes.com.au/traveller/inspiration/once-the-pinnacle-of-luxury-these-10-hotels-now-sit-abandoned-20250506-p5lx2w.html',
#                  'pubDate': '2025-05-07 19:00:00',
#                  'pubDateTZ': 'UTC',
#                  'sentiment': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS',
#                  'sentiment_stats': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS',
#                  'source_icon': 'https://i.bytvi.com/domain_icons/brisbanetimes.png',
#                  'source_id': 'brisbanetimes',
#                  'source_name': 'Brisbane Times',
#                  'source_priority': 22163,
#                  'source_url': 'https://www.brisbanetimes.com.au',
#                  'title': 'Once the pinnacle of luxury, these 10 hotels now sit abandoned',
#                  'video_url': None},
#                { 'ai_org': 'ONLY AVAILABLE IN CORPORATE PLANS',
#                  'ai_region': 'ONLY AVAILABLE IN CORPORATE PLANS',
#                  'ai_tag': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS',
#                  'article_id': 'd444c3ae7dd758249425ae09270749de',
#                  'category': ['top'],
#                  'content': 'ONLY AVAILABLE IN PAID PLANS',
#                  'country': ['australia'],
#                  'creator': ['Chris Leadbeater'],
#                  'description': 'The great and the good were once lured to these dead five-stars, '
#                                 'but now they are eerily derelict – though some could yet be '
#                                 'reborn.',
#                  'duplicate': True,
#                  'image_url': 'https://static.ffx.io/images/$zoom_0.2488251879699248,$multiply_0.7554,$ratio_1.777778,$width_1059,$x_0,$y_25/t_crop_custom/q_86,f_auto/c6276605c7dcf95114ef44834000961e182e9bbe',
#                  'keywords': ['travel / inspiration'],
#                  'language': 'english',
#                  'link': 'https://www.theage.com.au/traveller/inspiration/once-the-pinnacle-of-luxury-these-10-hotels-now-sit-abandoned-20250506-p5lx2w.html',
#                  'pubDate': '2025-05-07 19:00:00',
#                  'pubDateTZ': 'UTC',
#                  'sentiment': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS',
#                  'sentiment_stats': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS',
#                  'source_icon': 'https://i.bytvi.com/domain_icons/theage.png',
#                  'source_id': 'theage',
#                  'source_name': 'The Age',
#                  'source_priority': 44145,
#                  'source_url': 'https://www.theage.com.au',
#                  'title': 'Once the pinnacle of luxury, these 10 hotels now sit abandoned',
#                  'video_url': None},
#                { 'ai_org': 'ONLY AVAILABLE IN CORPORATE PLANS',
#                  'ai_region': 'ONLY AVAILABLE IN CORPORATE PLANS',
#                  'ai_tag': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS',
#                  'article_id': '7c92a0126f962472fff06b2a8c884392',
#                  'category': ['sports'],
#                  'content': 'ONLY AVAILABLE IN PAID PLANS',
#                  'country': ['zimbabwe'],
#                  'creator': ['Staff Reporter'],
#                  'description': 'Smoking the peace pipe: FC Platinum coach Norman Mapeza (second '
#                                 'left), Nehanda Radio journalist Tafadzwa Chigandiwa and '
#                                 'Munyaradzi Hwengwere, the consultant at Mejrkh Communications and '
#                                 'Media Advisory (second right) (Picture via Tafadzwa Chigandiwa)" '
#                                 'data-medium-file="https://i0.wp.com/nehandaradio.com/wp-content/uploads/2025/05/Norman-Mapeza-and-Tafadzwa-Chigandiwa-1.jpg?fit=300%2C225&ssl=1" '
#                                 'data-large-file="https://i0.wp.com/nehandaradio.com/wp-content/uploads/2025/05/Norman-Mapeza-and-Tafadzwa-Chigandiwa-1.jpg?fit=1024%2C768&ssl=1" '
#                                 '/>ZVISHAVANE - Former champions FC Platinum have reiterated their '
#                                 'commitment to fostering close, respectful, and transparent '
#                                 'relationships with the media, the club said in a statement issued '
#                                 'on Wednesday.The post FC Platinum committed to strengthening '
#                                 'media relations, club says in statement appeared first on Nehanda '
#                                 'Radio.',
#                  'duplicate': False,
#                  'image_url': 'https://nehandaradio.com/wp-content/uploads/2025/05/Norman-Mapeza-and-Tafadzwa-Chigandiwa-1.jpg',
#                  'keywords': [ 'munyaradzi hwengwere',
#                                'sports',
#                                'news',
#                                'fc platinum',
#                                'tafadzwa chigandiwa',
#                                'football',
#                                'norman mapeza'],
#                  'language': 'english',
#                  'link': 'https://nehandaradio.com/2025/05/07/fc-platinum-committed-to-strengthening-media-relations-club-says-in-statement/',
#                  'pubDate': '2025-05-07 13:16:49',
#                  'pubDateTZ': 'UTC',
#                  'sentiment': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS',
#                  'sentiment_stats': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS',
#                  'source_icon': 'https://i.bytvi.com/domain_icons/nehandaradio.jpg',
#                  'source_id': 'nehandaradio',
#                  'source_name': 'Nehanda Radio',
#                  'source_priority': 389454,
#                  'source_url': 'https://nehandaradio.com',
#                  'title': 'FC Platinum committed to strengthening media relations, club says in '
#                           'statement',
#                  'video_url': None},
#                { 'ai_org': 'ONLY AVAILABLE IN CORPORATE PLANS',
#                  'ai_region': 'ONLY AVAILABLE IN CORPORATE PLANS',
#                  'ai_tag': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS',
#                  'article_id': '9ec4f810907ba0b3f2bb33c62906b832',
#                  'category': ['world'],
#                  'content': 'ONLY AVAILABLE IN PAID PLANS',
#                  'country': ['russia'],
#                  'creator': None,
#                  'description': 'Top stories from the Russian press on Wednesday, May 7th',
#                  'duplicate': False,
#                  'image_url': 'https://cdn-media.tass.ru/width/1200_4ce85301/tass/m2/en/uploads/i/20250507/1444493.jpg',
#                  'keywords': ['press review'],
#                  'language': 'english',
#                  'link': 'https://tass.com/pressreview/1954145',
#                  'pubDate': '2025-05-07 10:00:00',
#                  'pubDateTZ': 'UTC',
#                  'sentiment': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS',
#                  'sentiment_stats': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS',
#                  'source_icon': 'https://i.bytvi.com/domain_icons/tass.png',
#                  'source_id': 'tass',
#                  'source_name': 'Тасс',
#                  'source_priority': 107047,
#                  'source_url': 'https://tass.ru',
#                  'title': 'Press review: 29 leaders to attend Moscow V-Day Parade as EU backs '
#                           'Russian gas ban by 2027',
#                  'video_url': None},
#                { 'ai_org': 'ONLY AVAILABLE IN CORPORATE PLANS',
#                  'ai_region': 'ONLY AVAILABLE IN CORPORATE PLANS',
#                  'ai_tag': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS',
#                  'article_id': 'f055f8b24e691f2cc94984488e93286b',
#                  'category': ['environment'],
#                  'content': 'ONLY AVAILABLE IN PAID PLANS',
#                  'country': ['tanzania'],
#                  'creator': None,
#                  'description': '[New Zimbabwe] CONSERVATION is under serious threat from mining '
#                                 'activities in protected areas countrywide, putting wild animals '
#                                 'at risk of extinction, a Zimbabwe Parks and Wildlife Management '
#                                 'Authority (ZimParks) official has said.',
#                  'duplicate': False,
#                  'image_url': None,
#                  'keywords': [ 'southern africa',
#                                'mining',
#                                'economy, business and finance',
#                                'wildlife',
#                                'environment',
#                                'zimbabwe'],
#                  'language': 'english',
#                  'link': 'https://allafrica.com/stories/202505070124.html',
#                  'pubDate': '2025-05-07 08:41:04',
#                  'pubDateTZ': 'UTC',
#                  'sentiment': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS',
#                  'sentiment_stats': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS',
#                  'source_icon': 'https://i.bytvi.com/domain_icons/allafrica.png',
#                  'source_id': 'allafrica',
#                  'source_name': 'Allafrica Tanzania',
#                  'source_priority': 79869,
#                  'source_url': 'https://allafrica.com/tanzania',
#                  'title': 'Zimbabwe: Conservation Under Threat As Mines Ministry Continues to '
#                           'Entertain Applications to Mine in Protected Areas - ZimParks',
#                  'video_url': None},
#                { 'ai_org': 'ONLY AVAILABLE IN CORPORATE PLANS',
#                  'ai_region': 'ONLY AVAILABLE IN CORPORATE PLANS',
#                  'ai_tag': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS',
#                  'article_id': '8bf6d8a44209bb0eddc907965f10c712',
#                  'category': ['top'],
#                  'content': 'ONLY AVAILABLE IN PAID PLANS',
#                  'country': ['zimbabwe'],
#                  'creator': ['Paidashe Mandivengerei'],
#                  'description': 'By Anna Chibamu CONSERVATION is under serious threat from mining '
#                                 'activities in protected areas countrywide, putting wild animals '
#                                 'at risk of extinction, a Zimbabwe Parks and Wildlife Management '
#                                 'Authority (ZimParks) official has said. Giving oral evidence to '
#                                 'the Tourism and Hospitality Industry Parliamentary Portfolio '
#                                 'Committee this Monday, ZimParks Corporate Secretary Nyasha '
#                                 'Mutyambizi said the Mines ministry continuedThe post Conservation '
#                                 'under threat as Mines Ministry continues to entertain '
#                                 'applications to mine in protected areas – ZimParks appeared first '
#                                 'on NewZimbabwe.com.',
#                  'duplicate': False,
#                  'image_url': 'https://s3-eu-west-2.amazonaws.com/newzimlive/wp-content/uploads/2025/02/26171635/Hwange-National-Park_11.jpg',
#                  'keywords': ['news headlines'],
#                  'language': 'english',
#                  'link': 'https://www.newzimbabwe.com/conservation-under-threat-as-mines-ministry-continues-to-entertain-applications-to-mine-in-protected-areas-zimparks/',
#                  'pubDate': '2025-05-07 02:44:52',
#                  'pubDateTZ': 'UTC',
#                  'sentiment': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS',
#                  'sentiment_stats': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS',
#                  'source_icon': 'https://i.bytvi.com/domain_icons/newzimbabwe.png',
#                  'source_id': 'newzimbabwe',
#                  'source_name': 'The Zimbabwe News',
#                  'source_priority': 187983,
#                  'source_url': 'https://www.newzimbabwe.com',
#                  'title': 'Conservation under threat as Mines Ministry continues to entertain '
#                           'applications to mine in protected areas – ZimParks',
#                  'video_url': None}],
#   'status': 'success',
#   'totalResults': 11}

# %% [markdown]
# Note how the total number of articles that are returned (articles per request) is 10.

# %% [markdown]
# # News Archive
#
# Unfortunately, accessing the news archive (articles past from the "latest news") is only under paid plans (check [here](https://newsdata.io/documentation/#news-archive)), with the most basic plan (and for which we would only have 6 months of historical data) costing 150 USD/month.

# %%
website = 'https://newsdata.io/api/1/'

search = 'archive?'

query = 'conflict'

url = website + search + 'apikey=' + api_key + '&q=' + query

example = requests.get(url = url)

print(url)

print(example.status_code)
# Out:
# https://newsdata.io/api/1/archive?apikey=pub_857112301fae34e55b800f06711f2df4d7b25&q=conflict
# 403

# %% [markdown]
# It returns an error, because we do not have access with the free plan to the archive news data.
